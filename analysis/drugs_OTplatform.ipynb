# %%
import os
# !pip install pandas
import pandas as pd
# !pip install seaborn
import seaborn as sns
# !pip installmatplotlib
import matplotlib.pyplot as plt
import requests
# !pip install mygene
import mygene
import json
# !pip install numpy
import numpy as np
# Out:
# ...
# ERROR: unknown command "installmatplotlib"
# ...

# %%
# this notebook stacks OT platform disease query tables for indication-specific drug information
# note these tables include studies indications and indirect indications
# these tables are combined with information extracted from the molecules files 
# for more specifc compound information

df_1 = pd.read_csv("OTplatform_drugs/MONDO_0100096-known-drugs.tsv", sep = "\t")

# %%
df_1.head()
# Out:
#        diseaseId diseaseName         drugId               drugName  \
# 0  MONDO_0100096    COVID-19     CHEMBL1433  DOXYCYCLINE ANHYDROUS
# 1  MONDO_0100096    COVID-19  CHEMBL1237022            TOCILIZUMAB
# 2  MONDO_0100096    COVID-19  CHEMBL1200694            SEVOFLURANE
# 3  MONDO_0100096    COVID-19      CHEMBL848           LENALIDOMIDE
# 4  MONDO_0100096    COVID-19  CHEMBL1201823              ABATACEPT
#
#              type                                  mechanismOfAction  \
# 0  Small molecule               Matrix metalloproteinase 8 inhibitor
# 1        Antibody     Interleukin-6 receptor alpha subunit inhibitor
# 2  Small molecule  GABA-A receptor; anion channel positive allost...
# 3  Small molecule           CRL4(CRBN) E3 ubiquitin ligase inhibitor
# 4         Protein     T-lymphocyte activation antigen CD86 inhibitor
#
#   actionType  symbol                                               name  \
# ...

# %%
# EFO_0000217 gastritis
df_EFO_0000217 = pd.read_csv("OTplatform_drugs/EFO_0000217-known-drugs.tsv", sep = "\t")
df_EFO_0000217_only = df_EFO_0000217[df_EFO_0000217['diseaseId']=="EFO_0000217"].copy()
print("EFO_0000217 gastritis")
print("# drugs:" + str(df_EFO_0000217_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000217_only["drugName"].copy().unique())))


# EFO_0000228 adenocarcinoma
df_EFO_0000228 = pd.read_csv("OTplatform_drugs/EFO_0000228-known-drugs.tsv", sep = "\t")
df_EFO_0000228_only = df_EFO_0000228[df_EFO_0000228['diseaseId']=="EFO_0000228"].copy()
print("EFO_0000228 adenocarcinoma")
print("# drugs:" + str(df_EFO_0000228_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000228_only["drugName"].copy().unique())))


# EFO_0000280 Barrett esophagus
df_EFO_0000280 = pd.read_csv("OTplatform_drugs/EFO_0000280-known-drugs.tsv", sep = "\t")
df_EFO_0000280_only = df_EFO_0000280[df_EFO_0000280['diseaseId']=="EFO_0000280"].copy()
print("EFO_0000280 Barrett esophagus")
print("# drugs:" + str(df_EFO_0000280_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000280_only["drugName"].copy().unique())))


# EFO_0000284 benign prostatic hyperplasia
df_EFO_0000284 = pd.read_csv("OTplatform_drugs/EFO_0000284-known-drugs.tsv", sep = "\t")
df_EFO_0000284_only = df_EFO_0000284[df_EFO_0000284['diseaseId']=="EFO_0000284"].copy()
print("EFO_0000284 benign prostatic hyperplasia")
print("# drugs:" + str(df_EFO_0000284_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000284_only["drugName"].copy().unique())))


# EFO_0000318 cardiomyopathy
df_EFO_0000318 = pd.read_csv("OTplatform_drugs/EFO_0000318-known-drugs.tsv", sep = "\t")
df_EFO_0000318_only = df_EFO_0000318[df_EFO_0000318['diseaseId']=="EFO_0000318"].copy()
print("EFO_0000318 cardiomyopathy")
print("# drugs:" + str(df_EFO_0000318_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000318_only["drugName"].copy().unique())))


# EFO_0000341 chronic obstructive pulmonary disease
df_EFO_0000341 = pd.read_csv("OTplatform_drugs/EFO_0000341-known-drugs.tsv", sep = "\t")
df_EFO_0000341_only = df_EFO_0000341[df_EFO_0000341['diseaseId']=="EFO_0000341"].copy()
print("EFO_0000341 chronic obstructive pulmonary disease")
print("# drugs:" + str(df_EFO_0000341_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000341_only["drugName"].copy().unique())))


# EFO_0000384 Crohn's disease
df_EFO_0000384 = pd.read_csv("OTplatform_drugs/EFO_0000384-known-drugs.tsv", sep = "\t")
df_EFO_0000384_only = df_EFO_0000384[df_EFO_0000384['diseaseId']=="EFO_0000384"].copy()
print("EFO_0000384 Crohn's disease")
print("# drugs:" + str(df_EFO_0000384_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000384_only["drugName"].copy().unique())))


# EFO_0000464 pulmonary emphysema
df_EFO_0000464 = pd.read_csv("OTplatform_drugs/EFO_0000464-known-drugs.tsv", sep = "\t")
df_EFO_0000464_only = df_EFO_0000464[df_EFO_0000464['diseaseId']=="EFO_0000464"].copy()
print("EFO_0000464 pulmonary emphysema")
print("# drugs:" + str(df_EFO_0000464_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000464_only["drugName"].copy().unique())))


# EFO_0000571 lung adenocarcinoma
df_EFO_0000571 = pd.read_csv("OTplatform_drugs/EFO_0000571-known-drugs.tsv", sep = "\t")
df_EFO_0000571_only = df_EFO_0000571[df_EFO_0000571['diseaseId']=="EFO_0000571"].copy()
print("EFO_0000571 lung adenocarcinoma")
print("# drugs:" + str(df_EFO_0000571_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000571_only["drugName"].copy().unique())))


# EFO_0000612 myocardial infarction
df_EFO_0000612 = pd.read_csv("OTplatform_drugs/EFO_0000612-known-drugs.tsv", sep = "\t")
df_EFO_0000612_only = df_EFO_0000612[df_EFO_0000612['diseaseId']=="EFO_0000612"].copy()
print("EFO_0000612 myocardial infarction")
print("# drugs:" + str(df_EFO_0000612_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000612_only["drugName"].copy().unique())))


# EFO_0000702 small cell lung carcinoma
df_EFO_0000702 = pd.read_csv("OTplatform_drugs/EFO_0000702-known-drugs.tsv", sep = "\t")
df_EFO_0000702_only = df_EFO_0000702[df_EFO_0000702['diseaseId']=="EFO_0000702"].copy()
print("EFO_0000702 small cell lung carcinoma")
print("# drugs:" + str(df_EFO_0000702_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000702_only["drugName"].copy().unique())))

# EFO_0000708 squamous cell lung carcinoma
df_EFO_0000708 = pd.read_csv("OTplatform_drugs/EFO_0000708-known-drugs.tsv", sep = "\t")
df_EFO_0000708_only = df_EFO_0000708[df_EFO_0000708['diseaseId']=="EFO_0000708"].copy()
print("EFO_0000708 squamous cell lung carcinoma")
print("# drugs:" + str(df_EFO_0000708_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0000708_only["drugName"].copy().unique())))

# EFO_0003060 non-small cell lung carcinoma
df_EFO_0003060 = pd.read_csv("OTplatform_drugs/EFO_0003060-known-drugs.tsv", sep = "\t")
df_EFO_0003060_only = df_EFO_0003060[df_EFO_0003060['diseaseId']=="EFO_0003060"].copy()
print("EFO_0003060 non-small cell lung carcinoma")
print("# drugs:" + str(df_EFO_0003060_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0003060_only["drugName"].copy().unique())))

# EFO_0003106 pneumonia
df_EFO_0003106 = pd.read_csv("OTplatform_drugs/EFO_0003106-known-drugs.tsv", sep = "\t")
df_EFO_0003106_only = df_EFO_0003106[df_EFO_0003106['diseaseId']=="EFO_0003106"].copy()
print("EFO_0003106 pneumonia")
print("# drugs:" + str(df_EFO_0003106_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0003106_only["drugName"].copy().unique())))

# EFO_0003884 chronic kidney disease
df_EFO_0003884 = pd.read_csv("OTplatform_drugs/EFO_0003884-known-drugs.tsv", sep = "\t")
df_EFO_0003884_only = df_EFO_0003884[df_EFO_0003884['diseaseId']=="EFO_0003884"].copy()
print("EFO_0003884 chronic kidney disease")
print("# drugs:" + str(df_EFO_0003884_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0003884_only["drugName"].copy().unique())))

# EFO_0004244 interstitial lung disease
df_EFO_0004244 = pd.read_csv("OTplatform_drugs/EFO_0004244-known-drugs.tsv", sep = "\t")
df_EFO_0004244_only = df_EFO_0004244[df_EFO_0004244['diseaseId']=="EFO_0004244"].copy()
print("EFO_0004244 interstitial lung disease")
print("# drugs:" + str(df_EFO_0004244_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0004244_only["drugName"].copy().unique())))

# EFO_0007328 influenza
df_EFO_0007328 = pd.read_csv("OTplatform_drugs/EFO_0007328-known-drugs.tsv", sep = "\t")
df_EFO_0007328_only = df_EFO_0007328[df_EFO_0007328['diseaseId']=="EFO_0007328"].copy()
print("EFO_0007328 influenza")
print("# drugs:" + str(df_EFO_0007328_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0007328_only["drugName"].copy().unique())))

# EFO_0009448 pulmonary fibrosis
df_EFO_0009448 = pd.read_csv("OTplatform_drugs/EFO_0009448-known-drugs.tsv", sep = "\t")
df_EFO_0009448_only = df_EFO_0009448[df_EFO_0009448['diseaseId']=="EFO_0009448"].copy()
print("EFO_0009448 pulmonary fibrosis")
print("# drugs:" + str(df_EFO_0009448_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0009448_only["drugName"].copy().unique())))

# EFO_0009608 stomach disorder
df_EFO_0009608 = pd.read_csv("OTplatform_drugs/EFO_0009608-known-drugs.tsv", sep = "\t")
df_EFO_0009608_only = df_EFO_0009608[df_EFO_0009608['diseaseId']=="EFO_0009608"].copy()
print("EFO_0009608 stomach disorder")
print("# drugs:" + str(df_EFO_0009608_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_0009608_only["drugName"].copy().unique())))

# EFO_1001938 B-cell non-Hodgkin lymphoma
df_EFO_1001938 = pd.read_csv("OTplatform_drugs/EFO_1001938-known-drugs.tsv", sep = "\t")
df_EFO_1001938_only = df_EFO_1001938[df_EFO_1001938['diseaseId']=="EFO_1001938"].copy()
print("EFO_1001938 B-cell non-Hodgkin lymphoma")
print("# drugs:" + str(df_EFO_1001938_only.shape[0]))
print("# unique drugs: "+ str(len(df_EFO_1001938_only["drugName"].copy().unique())))

# MONDO_0000709 Crohn ileitis - captured under chrohns disease, no specific drugs
#df_MONDO_0000709 = pd.read_csv("OTplatform_drugs/MONDO_0000709-known-drugs.tsv", sep = "\t")
#df_MONDO_0000709_only = df_MONDO_0000709[df_MONDO_0000709['diseaseId']=="MONDO_0000709"].copy()

# MONDO_0002492 acute kidney failure
df_MONDO_0002492 = pd.read_csv("OTplatform_drugs/MONDO_0002492-known-drugs.tsv", sep = "\t")
df_MONDO_0002492_only = df_MONDO_0002492[df_MONDO_0002492['diseaseId']=="MONDO_0002492"].copy()
print(" MONDO_0002492 acute kidney failure")
print("# drugs:" + str(df_MONDO_0002492_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0002492_only["drugName"].copy().unique())))

# MONDO_0004514 chronic rhinitis
df_MONDO_0004514 = pd.read_csv("OTplatform_drugs/MONDO_0004514-known-drugs.tsv", sep = "\t")
df_MONDO_0004514_only = df_MONDO_0004514[df_MONDO_0004514['diseaseId']=="MONDO_0004514"].copy()
print("MONDO_0004514 chronic rhinitis")
print("# drugs:" + str(df_MONDO_0004514_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0004514_only["drugName"].copy().unique())))

# MONDO_0005147 type 1 diabetes mellitus
df_MONDO_0005147 = pd.read_csv("OTplatform_drugs/MONDO_0005147-known-drugs.tsv", sep = "\t")
df_MONDO_0005147_only = df_MONDO_0005147[df_MONDO_0005147['diseaseId']=="MONDO_0005147"].copy()
print("MONDO_0005147 type 1 diabetes mellitus")
print("# drugs:" + str(df_MONDO_0005147_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0005147_only["drugName"].copy().unique())))

# MONDO_0007254 breast cancer
df_MONDO_0007254 = pd.read_csv("OTplatform_drugs/MONDO_0007254-known-drugs.tsv", sep = "\t")
df_MONDO_0007254_only = df_MONDO_0007254[df_MONDO_0007254['diseaseId']=="MONDO_0007254"].copy()
print("MONDO_0007254 breast cancer")
print("# drugs:" + str(df_MONDO_0007254_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0007254_only["drugName"].copy().unique())))

# MONDO_0007915 systemic lupus erythematosus
df_MONDO_0007915 = pd.read_csv("OTplatform_drugs/MONDO_0007915-known-drugs.tsv", sep = "\t")
df_MONDO_0007915_only = df_MONDO_0007915[df_MONDO_0007915['diseaseId']=="MONDO_0007915"].copy()
print("MONDO_0007915 systemic lupus erythematosus")
print("# drugs:" + str(df_MONDO_0007915_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0007915_only["drugName"].copy().unique())))

# MONDO_0009061 cystic fibrosis
df_MONDO_0009061 = pd.read_csv("OTplatform_drugs/MONDO_0009061-known-drugs.tsv", sep = "\t")
df_MONDO_0009061_only = df_MONDO_0009061[df_MONDO_0009061['diseaseId']=="MONDO_0009061"].copy()
print("MONDO_0009061 cystic fibrosis")
print("# drugs:" + str(df_MONDO_0009061_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0009061_only["drugName"].copy().unique())))

# MONDO_0015517 common variable immunodeficiency
df_MONDO_0015517 = pd.read_csv("OTplatform_drugs/MONDO_0015517-known-drugs.tsv", sep = "\t")
df_MONDO_0015517_only = df_MONDO_0015517[df_MONDO_0015517['diseaseId']=="MONDO_0015517"].copy()
print("MONDO_0015517 common variable immunodeficiency")
print("# drugs:" + str(df_MONDO_0015517_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0015517_only["drugName"].copy().unique())))

# MONDO_0018906 follicular lymphoma
df_MONDO_0018906 = pd.read_csv("OTplatform_drugs/MONDO_0018906-known-drugs.tsv", sep = "\t")
df_MONDO_0018906_only = df_MONDO_0018906[df_MONDO_0018906['diseaseId']=="MONDO_0018906"].copy()
print("MONDO_0018906 follicular lymphoma")
print("# drugs:" + str(df_MONDO_0018906_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0018906_only["drugName"].copy().unique())))

# MONDO_0100096 COVID-19
df_MONDO_0100096 = pd.read_csv("OTplatform_drugs/MONDO_0100096-known-drugs.tsv", sep = "\t")
df_MONDO_0100096_only = df_MONDO_0100096[df_MONDO_0100096['diseaseId']=="MONDO_0100096"].copy()
print("MONDO_0100096 COVID-19")
print("# drugs:" + str(df_MONDO_0100096_only.shape[0]))
print("# unique drugs: "+ str(len(df_MONDO_0100096_only["drugName"].copy().unique())))
# Out:
# EFO_0000217 gastritis
# # drugs:11
# # unique drugs: 5
# EFO_0000228 adenocarcinoma
# # drugs:256
# # unique drugs: 50
# EFO_0000280 Barrett esophagus
# # drugs:72
# # unique drugs: 17
# EFO_0000284 benign prostatic hyperplasia
# # drugs:187
# # unique drugs: 34
# EFO_0000318 cardiomyopathy
# # drugs:40
# # unique drugs: 20
# EFO_0000341 chronic obstructive pulmonary disease
# # drugs:844
# # unique drugs: 180
# EFO_0000384 Crohn's disease
# # drugs:506
# # unique drugs: 109
# EFO_0000464 pulmonary emphysema
# # drugs:71
# # unique drugs: 37
# EFO_0000571 lung adenocarcinoma
# # drugs:532
# # unique drugs: 49
# EFO_0000612 myocardial infarction
# # drugs:410
# # unique drugs: 120
# EFO_0000702 small cell lung carcinoma
# # drugs:1226
# # unique drugs: 165
# EFO_0000708 squamous cell lung carcinoma
# # drugs:447
# # unique drugs: 47
# EFO_0003060 non-small cell lung carcinoma
# # drugs:5533
# # unique drugs: 477
# EFO_0003106 pneumonia
# # drugs:116
# # unique drugs: 48
# ...

# %%
frames = [

# EFO_0000217 gastritis
df_EFO_0000217_only,

# EFO_0000228 adenocarcinoma
df_EFO_0000228_only,

# EFO_0000280 Barrett esophagus
df_EFO_0000280_only,

# EFO_0000284 benign prostatic hyperplasia
df_EFO_0000284_only,

# EFO_0000318 cardiomyopathy
df_EFO_0000318_only,

# EFO_0000341 chronic obstructive pulmonary disease
df_EFO_0000341_only,

# EFO_0000384 Crohn's disease
df_EFO_0000384_only,

# EFO_0000464 pulmonary emphysema
df_EFO_0000464_only,

# EFO_0000571 lung adenocarcinoma
df_EFO_0000571_only,

# EFO_0000612 myocardial infarction
df_EFO_0000612_only,

# EFO_0000702 small cell lung carcinoma
df_EFO_0000702_only,

# EFO_0000708 squamous cell lung carcinoma
df_EFO_0000708_only,

# EFO_0003060 non-small cell lung carcinoma
df_EFO_0003060_only,

# EFO_0003106 pneumonia
df_EFO_0003106_only,

# EFO_0003884 chronic kidney disease
df_EFO_0003884_only,

# EFO_0004244 interstitial lung disease
df_EFO_0004244_only,

# EFO_0007328 influenza
df_EFO_0007328_only,

# EFO_0009448 pulmonary fibrosis
df_EFO_0009448_only,

# EFO_0009608 stomach disorder
#df_EFO_0009608_only

# EFO_1001938 B-cell non-Hodgkin lymphoma
df_EFO_1001938_only,

# MONDO_0000709 Crohn ileitis - captured under chrohns disease, no specific drugs
#df_MONDO_0000709 = pd.read_csv("OTplatform_drugs/MONDO_0000709-known-drugs.tsv", sep = "\t")
#df_MONDO_0000709_only = df_MONDO_0000709[df_MONDO_0000709['diseaseId']=="MONDO_0000709"].copy()

# MONDO_0002492 acute kidney failure
df_MONDO_0002492_only,

# MONDO_0004514 chronic rhinitis
df_MONDO_0004514_only,

# MONDO_0005147 type 1 diabetes mellitus
df_MONDO_0005147_only,

# MONDO_0007254 breast cancer
df_MONDO_0007254_only,

# MONDO_0007915 systemic lupus erythematosus
df_MONDO_0007915_only,

# MONDO_0009061 cystic fibrosis
df_MONDO_0009061_only,

# MONDO_0015517 common variable immunodeficiency
df_MONDO_0015517_only,

# MONDO_0018906 follicular lymphoma
df_MONDO_0018906_only,


# MONDO_0100096 COVID-19
df_MONDO_0100096_only]

result = pd.concat(frames)
result.reset_index()
result.shape
#len(result["drugName"].copy().unique())
#len(result["symbol"].copy().unique())
# Out:
# (22505, 12)

# %%
result
# Out:
#           diseaseId diseaseName         drugId            drugName  \
# 3       EFO_0000217   gastritis  CHEMBL3183075          NIZATIDINE
# 7       EFO_0000217   gastritis      CHEMBL480        LANSOPRAZOLE
# 8       EFO_0000217   gastritis     CHEMBL1503          OMEPRAZOLE
# 9       EFO_0000217   gastritis  CHEMBL1201320        ESOMEPRAZOLE
# 10      EFO_0000217   gastritis    CHEMBL60889           MOSAPRIDE
# ...             ...         ...            ...                 ...
# 1619  MONDO_0100096    COVID-19      CHEMBL107          COLCHICINE
# 1620  MONDO_0100096    COVID-19  CHEMBL1201558  INTERFERON ALFA-2B
# 1621  MONDO_0100096    COVID-19  CHEMBL2108730           SARILUMAB
# 1622  MONDO_0100096    COVID-19  CHEMBL1201558  INTERFERON ALFA-2B
# 1623  MONDO_0100096    COVID-19     CHEMBL1535  HYDROXYCHLOROQUINE
#
#                 type                                mechanismOfAction  \
# 3     Small molecule                 Histamine H2 receptor antagonist
# ...

# %%
result.to_csv("OTplatform_drugs_targets_02282024.csv")
